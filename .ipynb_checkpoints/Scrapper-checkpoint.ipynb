# %%
import selenium
import pandas as pd

# %%
import os
import numpy as np
from google_images_download import google_images_download

# %%
folder = "C:\\Users\\massa\\Documents\\zoohackadosparsa\\"
file = "especies_aves_extincao.csv"

# %%
os.listdir(folder)
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'especies.csv',
#  'especies_aves_extincao.csv',
#  'Imagens',
#  'README.md',
#  'Scrapper.ipynb',
#  'Scrapper_Config',
#  'tutorial_git_activate.png']

# %%
df = pd.read_csv(folder+file)

# %%
df
# Out:
#                                                Especie            Estado
# 0    Crypturellus noctivagus noctivagus (jaó-do-sul...  Estado ICMBio VU
# 1           Crypturellus noctivagus zabele (zabelê) NE  Estado ICMBio VU
# 2              Nothura minor (codorna-mineira) VU IUCN  Estado ICMBio EN
# 3             Taoniscus nanus (inhambu-carapé) VU IUCN  Estado ICMBio EN
# 4                        Tinamus tao (azulona) VU IUCN  Estado ICMBio VU
# 5         Mergus octosetaceus (pato-mergulhão) CR IUCN  Estado ICMBio CR
# 6                Aburria jacutinga (jacutinga) EN IUCN  Estado ICMBio EN
# 7         Crax blumenbachii (mutum-do-sudeste) EN IUCN  Estado ICMBio CR
# 8               Crax globulosa (mutum-de-fava) EN IUCN  Estado ICMBio EN
# 9    Crax fasciolata pinima (mutum-de-penacho) CR IUCN  Estado ICMBio CR
# 10              Pauxi mitu (mutum-do-nordeste) EW IUCN  Estado ICMBio EW
# 11                Penelope jacucaca (jacucaca) VU IUCN  Estado ICMBio VU
# ...

# %%
df["nome_c"] = df.Especie.apply(lambda s: s.split(" (")[0])

# %%
df_teste = df["nome_c"].head(10)

# %%
response = google_images_download.googleimagesdownload()

# %%
arguments = {'keywords': esp,  'output_directory': folder+"Imagens\\", 'image_directory': esp, 'limit': }

# %%
for esp in df["nome_c"]:
    response.download()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8665e7ae126c> in <module>
#       1 for esp in df["nome_c"]:
# ----> 2     google_images_download.google_images_download(keywords=esp,  output_directory=folder+"Imagens\\", image_directory=esp)
#
# AttributeError: module 'google_images_download.google_images_download' has no attribute 'google_images_download'

# %%
# Out:
# <module 'google_images_download.google_images_download' from 'c:\\users\\massa\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\google_images_download\\google_images_download.py'>
